# %%
import numpy as np
import pandas as pd
import PIL as pil
import glob
from PIL import Image
from pandas import DataFrame
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
labels = pd.read_csv("C:/Users/kuberti/OneDrive - Eastside Preparatory School/train/train_labels.csv")
files = glob.glob("C:/Users/kuberti/OneDrive - Eastside Preparatory School/train/*.tif")
images = []
n = 0
for myFile in files:
    image = Image.open(myFile)
    #image.show()
    #look up label for myFile in labels
    label = labels.iat[n, 1]
    images.append((image, label))
    n = n+1
    if n==20:
        break
        
images = DataFrame(images,columns=['images','label'])
#print(images)
labels.head()

 

#Train data
# train = []
# train_labels = []
# files = glob.glob ("/data/train/class1/*.png") # your image path
# for myFile in files:
# image = cv2.imread (myFile)
#  train.append (image)
#  train_labels.append([1., 0.])
# files = glob.glob ("/data/train/class2/*.png")
# for myFile in files:
# image = cv2.imread (myFile)
#  train.append (image)
#  train_labels.append([0., 1.])
# train = np.array(train,dtype='float32') #as mnist
# train_labels = np.array(train_labels,dtype='float64') #as mnist
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %%
from numpy import asarray
temp = np.array([asarray(images.iat[0,0])])
#print(temp)
for i in range(19):
    temp = np.concatenate((temp, np.array([asarray(images.iat[i+1,0])])), axis=0)
meanreds = []
meanblues = []
meangreens = []
iS = []
for i in range (20):
    image = temp[i]
    sum_temp=image.sum(axis=(0, 1))
    meanred = sum_temp[0]/(96**2)
    meangreen = sum_temp[1]/(96**2)
    meanblue = sum_temp[2]/(96**2)
    meanreds.append(meanred)
    meanblues.append(meanblue)
    meangreens.append(meangreen)
    iS.append(i)
#     print("meanred for " + str(i) + " is "+ str(meanred))
#     print("meangreen for " + str(i)+ " is " + str(meangreen))
#     print("meanblue for " + str(i) + " is " + str(meanblue))
    

# cancerous = []
# noncancerous = []
# for i in range (0, 20):
#     if temp.iat("labels") == 0:
#         noncancerous.append(temp[i])
#     else:
#         cancerous.append(temp[i])
        
plt.plot(iS,meanreds) 
plt.plot(iS,meangreens) 
plt.plot(iS,meanblues) 
    

#print(image1)
# avg_temp = temp.mean(axis=0)
# im_avtemp = Image.fromarray(avg_temp, mode="RGB")
#im_avtemp.show()
# Out:
# meanred for 0 is 197.41514756944446
# meangreen for 0 is 142.87814670138889
# meanblue for 0 is 170.42013888888889
# meanred for 1 is 231.80479600694446
# meangreen for 1 is 216.88682725694446
# meanblue for 1 is 222.53754340277777
# meanred for 2 is 140.61838107638889
# meangreen for 2 is 101.46299913194444
# meanblue for 2 is 134.14398871527777
# meanred for 3 is 223.98046875
# meangreen for 3 is 193.38682725694446
# meanblue for 3 is 223.50477430555554
# meanred for 4 is 152.35405815972223
# meangreen for 4 is 96.61436631944444
# meanblue for 4 is 175.67013888888889
# meanred for 5 is 143.72894965277777
# meangreen for 5 is 97.76334635416667
# meanblue for 5 is 128.67133246527777
# meanred for 6 is 229.69259982638889
# meangreen for 6 is 189.45182291666666
# meanblue for 6 is 204.900390625
# meanred for 7 is 242.54958767361111
# meangreen for 7 is 235.44086371527777
# meanblue for 7 is 237.38292100694446
# meanred for 8 is 175.28917100694446
# ...

# %%
for i in range (1):
    if images["label"][i] == 0:
        cancerous.append(images.loc[i])
    #print("cancerous =" + str(cancerous))
    if images["label"][i] == 1:
        noncancerous.append(images.loc[i])
    #print("noncancerous =" + str(noncancerous))

tempcancer = np.array([asarray(cancerous.index(0,0))])
#print(temp)
for i in range(tempcancer):
    tempcancer = np.concatenate((tempcancer, np.array([asarray(images.loc[i+1,0])])), axis=0)
  
tempnoncancer = np.array([asarray(images.index(0,0))])
#print(temp)
for i in range (19):
    tempnoncaner = np.concatenate((tempnoncaner, np.array([asarray(images.loc[i+1,0])])), axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-70c214b7eb79> in <module>
#       7     #print("noncancerous =" + str(noncancerous))
#       8
# ----> 9 tempcancer = np.array([asarray(cancerous.index(0))])
#      10 #print(temp)
#      11 for i in range(tempcancer):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
